# %% [markdown]
# ### 00. Initial imports and PATH dirs definition

# %%
import random
from pathlib import Path
import polars as pl
import time
import os
from shutil import rmtree
from prerequisites import attack_update, label_casting

MERGED_PATH = Path(Path.cwd(), "02_attacks_merged")
SHUFFLED_PATH = Path(Path.cwd(), "03_attacks_shuffled")

os.makedirs(MERGED_PATH, exist_ok=True)

try:
    os.makedirs(SHUFFLED_PATH)
except FileExistsError:
    rmtree(SHUFFLED_PATH)
    os.makedirs(SHUFFLED_PATH)
    
DS_SCHEMA = label_casting("00_type_cast_data/type_list.txt")

# %% [markdown]
# ### 01. Appending source files

# %%
def whitelist_check(attack_name: str, whitelist: list, blacklist: list = []) -> bool:   
    # if there is a benign traffic - pass it
    if attack_name.lower().find("benign") != -1:
        return True
    # if there is blacklisted element
    for el in blacklist:
        if attack_name.find(el) != -1:
            return False
    # if given element is on the whitelist
    for el in whitelist:
        if attack_name.find(el) != -1:
            return True
        
    # if there is no element on "whitelist" - everything is passed
    if len(whitelist) == 0:
        return True

attack_names = []
attack_paths = []

whitelist = []#["DoS", "Mirai"]
blacklist = []#["DDoS"]

for path_attack in MERGED_PATH.iterdir():
    if not whitelist_check(path_attack.stem, whitelist, blacklist):
        continue
    if path_attack.stem.find("Benign") != -1:
        attack_names.insert(0, path_attack.stem)
        attack_paths.insert(0, path_attack)
        continue
    
    attack_names.append(path_attack.stem)
    attack_paths.append(path_attack)

# %%
print(attack_names)
# Out:
# ['00_Benign_Final', 'Backdoor_Malware', 'BrowserHijacking', 'CommandInjection', 'DDoS-ACK_Fragmentation', 'DDoS-HTTP_Flood', 'DDoS-ICMP_Flood', 'DDoS-ICMP_Fragmentation', 'DDoS-SlowLoris', 'DDoS-TCP_Flood', 'DDoS-UDP_Flood', 'DDoS-UDP_Fragmentation', 'DictionaryBruteForce', 'DNS_Spoofing', 'DoS-HTTP_Flood', 'DoS-TCP_Flood', 'DoS-UDP_Flood', 'Mirai-greeth_flood', 'Mirai-greip_flood', 'Mirai-udpplain', 'MITM-ArpSpoofing', 'Recon-HostDiscovery', 'Recon-OSScan', 'Recon-PingSweep', 'Recon-PortScan', 'SqlInjection', 'Uploading_Attack', 'VulnerabilityScan', 'XSS']

# %% [markdown]
# ### 02. Attack shuffling

# %% [markdown]
# Defining the function

# %%
def shuffle_attack(attack_path: Path, benign_path: Path, att_name: str, it, att_list_len):
    with open(Path(SHUFFLED_PATH, "{}-shuffled.csv".format(att_name)), "w") as file_shuffled:
        log = "SHUFFLING attack {}/{}: {}".format(it, att_list_len, att_name)
        attack_update(log)
        print(log)
        
        if_benign_finished = False
        if_attack_finished = False
        
        benign_file = open(benign_path, "r")
        attack_file = open(attack_path, "r")
        
        header_benign = benign_file.readline()
        attack_file.readline()
        
        file_shuffled.write(header_benign)
        
        attack_num_counter = 0
        benign_num_counter = 0
        
        time_processing_start = time.time()
        
        while(True):
            if random.randint(1, 10) > 3 and not if_benign_finished:
                line = benign_file.readline()
                # if benign file reaches EOF
                if line == "":
                    if_benign_finished = True
                    continue
                benign_num_counter += 1
                file_shuffled.write(line)
            elif not if_attack_finished:
                line = attack_file.readline()
                # if attack file reaches EOF
                if line == "":
                    if_attack_finished = True
                    continue
                attack_num_counter += 1
                file_shuffled.write(line)
            else:
                break
                
        benign_file.close()
        attack_file.close()
        
        time_processing_stop = time.time()
        
        INFO_end = "INFO: dataset creation of an attack {} completed with\n attacks: {}\n benign: {}\nTIME ELAPSED: {}s".format(att_name, attack_num_counter, benign_num_counter, round(time_processing_stop-time_processing_start, 2))
        
        print(INFO_end)

# %% [markdown]
# Iterate over each `attack_path` and shuffle distinct attacks with benign traffic

# %%
for it in range(1, len(attack_paths)):
    shuffle_attack(
        attack_path = attack_paths[it],
        benign_path = attack_paths[0],
        att_name = attack_names[it],
        it = it,
        att_list_len = len(attack_paths)-1
    )
# Out:
# SHUFFLING attack 1/28: Backdoor_Malware
# INFO: dataset creation of an attack Backdoor_Malware completed with
#  attacks: 622
#  benign: 1278
# TIME ELAPSED: 0.05s
# SHUFFLING attack 2/28: BrowserHijacking
# INFO: dataset creation of an attack BrowserHijacking completed with
#  attacks: 933
#  benign: 2084
# TIME ELAPSED: 0.08s
# SHUFFLING attack 3/28: CommandInjection
# INFO: dataset creation of an attack CommandInjection completed with
#  attacks: 847
#  benign: 2100
# TIME ELAPSED: 0.08s
# SHUFFLING attack 4/28: DDoS-ACK_Fragmentation
# INFO: dataset creation of an attack DDoS-ACK_Fragmentation completed with
#  attacks: 8821164
#  benign: 135740
# TIME ELAPSED: 208.25s
# SHUFFLING attack 5/28: DDoS-HTTP_Flood
# INFO: dataset creation of an attack DDoS-HTTP_Flood completed with
#  attacks: 591468
#  benign: 135740
# TIME ELAPSED: 19.78s
# SHUFFLING attack 6/28: DDoS-ICMP_Flood
# INFO: dataset creation of an attack DDoS-ICMP_Flood completed with
#  attacks: 71242
#  benign: 135740
# TIME ELAPSED: 4.92s
# SHUFFLING attack 7/28: DDoS-ICMP_Fragmentation
# INFO: dataset creation of an attack DDoS-ICMP_Fragmentation completed with
#  attacks: 170579
#  benign: 135740
# TIME ELAPSED: 7.22s
# SHUFFLING attack 8/28: DDoS-SlowLoris
# INFO: dataset creation of an attack DDoS-SlowLoris completed with
#  attacks: 157161
#  benign: 135740
# TIME ELAPSED: 9.23s
# SHUFFLING attack 9/28: DDoS-TCP_Flood
# INFO: dataset creation of an attack DDoS-TCP_Flood completed with
#  attacks: 8793176
#  benign: 135740
# TIME ELAPSED: 215.27s
# SHUFFLING attack 10/28: DDoS-UDP_Flood
# INFO: dataset creation of an attack DDoS-UDP_Flood completed with
#  attacks: 141465
#  benign: 135740
# TIME ELAPSED: 7.38s
# SHUFFLING attack 11/28: DDoS-UDP_Fragmentation
# INFO: dataset creation of an attack DDoS-UDP_Fragmentation completed with
#  attacks: 48399
#  benign: 112719
# TIME ELAPSED: 3.76s
# SHUFFLING attack 12/28: DictionaryBruteForce
# INFO: dataset creation of an attack DictionaryBruteForce completed with
#  attacks: 4261
#  benign: 9642
# TIME ELAPSED: 0.42s
# SHUFFLING attack 13/28: DNS_Spoofing
# INFO: dataset creation of an attack DNS_Spoofing completed with
#  attacks: 20602
#  benign: 47356
# TIME ELAPSED: 2.4s
# SHUFFLING attack 14/28: DoS-HTTP_Flood
# INFO: dataset creation of an attack DoS-HTTP_Flood completed with
#  attacks: 1857628
#  benign: 135740
# TIME ELAPSED: 49.96s
# SHUFFLING attack 15/28: DoS-TCP_Flood
# INFO: dataset creation of an attack DoS-TCP_Flood completed with
#  attacks: 3019006
#  benign: 135740
# TIME ELAPSED: 75.06s
# SHUFFLING attack 16/28: DoS-UDP_Flood
# INFO: dataset creation of an attack DoS-UDP_Flood completed with
#  attacks: 166904
#  benign: 135740
# TIME ELAPSED: 9.54s
# SHUFFLING attack 17/28: Mirai-greeth_flood
# INFO: dataset creation of an attack Mirai-greeth_flood completed with
#  attacks: 44742
#  benign: 104331
# TIME ELAPSED: 3.94s
# SHUFFLING attack 18/28: Mirai-greip_flood
# INFO: dataset creation of an attack Mirai-greip_flood completed with
#  attacks: 58195
#  benign: 135740
# TIME ELAPSED: 4.86s
# SHUFFLING attack 19/28: Mirai-udpplain
# INFO: dataset creation of an attack Mirai-udpplain completed with
#  attacks: 43681
#  benign: 101773
# TIME ELAPSED: 3.81s
# SHUFFLING attack 20/28: MITM-ArpSpoofing
# INFO: dataset creation of an attack MITM-ArpSpoofing completed with
#  attacks: 20859
#  benign: 48317
# TIME ELAPSED: 2.01s
# SHUFFLING attack 21/28: Recon-HostDiscovery
# INFO: dataset creation of an attack Recon-HostDiscovery completed with
#  attacks: 629799
#  benign: 135740
# TIME ELAPSED: 19.89s
# SHUFFLING attack 22/28: Recon-OSScan
# INFO: dataset creation of an attack Recon-OSScan completed with
#  attacks: 163982
#  benign: 135740
# TIME ELAPSED: 7.47s
# SHUFFLING attack 23/28: Recon-PingSweep
# INFO: dataset creation of an attack Recon-PingSweep completed with
#  attacks: 1034
#  benign: 2420
# TIME ELAPSED: 0.09s
# SHUFFLING attack 24/28: Recon-PortScan
# INFO: dataset creation of an attack Recon-PortScan completed with
#  attacks: 199313
#  benign: 135740
# TIME ELAPSED: 8.22s
# SHUFFLING attack 25/28: SqlInjection
# INFO: dataset creation of an attack SqlInjection completed with
#  attacks: 3545
#  benign: 8463
# TIME ELAPSED: 0.32s
# SHUFFLING attack 26/28: Uploading_Attack
# INFO: dataset creation of an attack Uploading_Attack completed with
#  attacks: 286
#  benign: 680
# TIME ELAPSED: 0.03s
# SHUFFLING attack 27/28: VulnerabilityScan
# INFO: dataset creation of an attack VulnerabilityScan completed with
#  attacks: 268964
#  benign: 135740
# TIME ELAPSED: 10.17s
# SHUFFLING attack 28/28: XSS
# INFO: dataset creation of an attack XSS completed with
#  attacks: 739
#  benign: 1718
# TIME ELAPSED: 0.06s

# %% [markdown]
# ### 03. Test/Train division

# %%
import numpy as np

INPUT_PATH = Path(Path.cwd(), "03.2_attacks_shuffled_divided")
DIVIDED_TRAIN_PATH = Path(INPUT_PATH, "train")
DIVIDED_TEST_PATH = Path(INPUT_PATH, "test")

try:
    os.makedirs(INPUT_PATH)
    os.makedirs(DIVIDED_TRAIN_PATH)
    os.makedirs(DIVIDED_TEST_PATH)
except FileExistsError:
    rmtree(INPUT_PATH)
    os.makedirs(INPUT_PATH)
    os.makedirs(DIVIDED_TRAIN_PATH)
    os.makedirs(DIVIDED_TEST_PATH)

# %% [markdown]
# Defining the function

# %%
def divide_test_train(att_path: Path, att_name: str, it, att_list_len):
    DIVIDED_TRAIN_ATT_PATH = Path(DIVIDED_TRAIN_PATH, "train_{}.csv".format(att_name))
    DIVIDED_TEST_ATT_PATH = Path(DIVIDED_TEST_PATH, "test_{}.csv".format(att_name))
    
    divided_train = open(DIVIDED_TRAIN_ATT_PATH, "w")
    divided_test = open(DIVIDED_TEST_ATT_PATH, "w")
    attack_source = open(att_path, "r")
    
    # creating header
    header = attack_source.readline()
    divided_test.write(header)
    divided_train.write(header)
    
    while(True):
        line = attack_source.readline()
        if line == "":
            break
        if random.randint(1, 10) > 8:
            divided_test.write(line)
        else:
            divided_train.write(line)
    
    # closing
    attack_source.close()
    divided_train.close()
    divided_test.close()
    
    # quick check of attack-to-benign ratio
    # --------------------------------------
    train_df = pl.read_csv(DIVIDED_TRAIN_ATT_PATH, schema_overrides=DS_SCHEMA)
    test_df = pl.read_csv(DIVIDED_TEST_ATT_PATH, schema_overrides=DS_SCHEMA)
    
    unique_train_names, unique_train_counts = np.unique(train_df.select('label').to_numpy(), return_counts=True)
    unique_test_names, unique_test_counts = np.unique(test_df.select('label').to_numpy(), return_counts=True)
    
    
    print("{}/{} - {}\n======================".format(it, att_list_len, att_name))
    
    print("TRAIN dataset:\n\t{} - {} ({}%)\n\t{} - {} ({}%)".format(
        unique_train_names[0], unique_train_counts[0], round((unique_train_counts[0]/(unique_train_counts[0]+unique_train_counts[1]))*100, 2),
        unique_train_names[1], unique_train_counts[1], round((unique_train_counts[1]/(unique_train_counts[0]+unique_train_counts[1]))*100, 2)
    ))
    
    print("TEST dataset:\n\t{} - {} ({}%)\n\t{} - {} ({}%)\n\n".format(
        unique_test_names[0], unique_test_counts[0], round((unique_test_counts[0]/(unique_test_counts[0]+unique_test_counts[1]))*100, 2),
        unique_test_names[1], unique_test_counts[1], round((unique_test_counts[1]/(unique_test_counts[0]+unique_test_counts[1]))*100, 2)
    ))
    # --------------------------------------

# %% [markdown]
# Dividing the dataset into test and train parts

# %%
ATT_LIST_LEN = len([att for att in SHUFFLED_PATH.iterdir() if att.is_file()])

counter = 1
for el in SHUFFLED_PATH.iterdir():
    if not el.is_file():
        continue
    divide_test_train(
        el,
        el.stem,
        counter,
        ATT_LIST_LEN
    )
    counter += 1
# Out:
# 1/28 - Backdoor_Malware-shuffled
# ======================
# TRAIN dataset:
# 	Backdoor_Malware - 509 (33.38%)
# 	BenignTraffic - 1016 (66.62%)
# TEST dataset:
# 	Backdoor_Malware - 113 (30.13%)
# 	BenignTraffic - 262 (69.87%)
#
#
# 2/28 - BrowserHijacking-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 1684 (69.24%)
# 	BrowserHijacking - 748 (30.76%)
# TEST dataset:
# 	BenignTraffic - 400 (68.38%)
# 	BrowserHijacking - 185 (31.62%)
#
#
# 3/28 - CommandInjection-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 1668 (71.56%)
# 	CommandInjection - 663 (28.44%)
# TEST dataset:
# 	BenignTraffic - 432 (70.13%)
# 	CommandInjection - 184 (29.87%)
#
#
# 4/28 - DDoS-ACK_Fragmentation-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108874 (1.52%)
# 	DDoS-ACK_Fragmentation - 7057223 (98.48%)
# TEST dataset:
# 	BenignTraffic - 26866 (1.5%)
# 	DDoS-ACK_Fragmentation - 1763941 (98.5%)
#
#
# 5/28 - DDoS-HTTP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108642 (18.68%)
# 	DDoS-HTTP_Flood- - 472952 (81.32%)
# TEST dataset:
# 	BenignTraffic - 27098 (18.61%)
# 	DDoS-HTTP_Flood- - 118516 (81.39%)
#
#
# 6/28 - DDoS-ICMP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108591 (65.58%)
# 	DDoS-ICMP_Flood - 57001 (34.42%)
# TEST dataset:
# 	BenignTraffic - 27149 (65.59%)
# 	DDoS-ICMP_Flood - 14241 (34.41%)
#
#
# 7/28 - DDoS-ICMP_Fragmentation-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108540 (44.29%)
# 	DDoS-ICMP_Fragmentation - 136511 (55.71%)
# TEST dataset:
# 	BenignTraffic - 27200 (44.4%)
# 	DDoS-ICMP_Fragmentation - 34068 (55.6%)
#
#
# 8/28 - DDoS-SlowLoris-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108700 (46.38%)
# 	DDoS-SlowLoris - 125677 (53.62%)
# TEST dataset:
# 	BenignTraffic - 27040 (46.2%)
# 	DDoS-SlowLoris - 31484 (53.8%)
#
#
# 9/28 - DDoS-TCP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108419 (1.52%)
# 	DDoS-TCP_Flood - 7036224 (98.48%)
# TEST dataset:
# 	BenignTraffic - 27321 (1.53%)
# 	DDoS-TCP_Flood - 1756952 (98.47%)
#
#
# 10/28 - DDoS-UDP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108552 (48.93%)
# 	DDoS-UDP_Flood - 113320 (51.07%)
# TEST dataset:
# 	BenignTraffic - 27188 (49.14%)
# 	DDoS-UDP_Flood - 28145 (50.86%)
#
#
# 11/28 - DDoS-UDP_Fragmentation-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 90431 (70.05%)
# 	DDoS-UDP_Fragmentation - 38672 (29.95%)
# TEST dataset:
# 	BenignTraffic - 22288 (69.62%)
# 	DDoS-UDP_Fragmentation - 9727 (30.38%)
#
#
# 12/28 - DictionaryBruteForce-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 7740 (69.22%)
# 	DictionaryBruteForce - 3442 (30.78%)
# TEST dataset:
# 	BenignTraffic - 1902 (69.9%)
# 	DictionaryBruteForce - 819 (30.1%)
#
#
# 13/28 - DNS_Spoofing-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 38034 (69.78%)
# 	DNS_Spoofing - 16469 (30.22%)
# TEST dataset:
# 	BenignTraffic - 9322 (69.28%)
# 	DNS_Spoofing - 4133 (30.72%)
#
#
# 14/28 - DoS-HTTP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108574 (6.81%)
# 	DoS-HTTP_Flood - 1486431 (93.19%)
# TEST dataset:
# 	BenignTraffic - 27166 (6.82%)
# 	DoS-HTTP_Flood - 371197 (93.18%)
#
#
# 15/28 - DoS-TCP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108641 (4.3%)
# 	DoS-TCP_Flood - 2415296 (95.7%)
# TEST dataset:
# 	BenignTraffic - 27099 (4.3%)
# 	DoS-TCP_Flood - 603710 (95.7%)
#
#
# 16/28 - DoS-UDP_Flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108489 (44.79%)
# 	DoS-UDP_Flood - 133706 (55.21%)
# TEST dataset:
# 	BenignTraffic - 27251 (45.08%)
# 	DoS-UDP_Flood - 33198 (54.92%)
#
#
# 17/28 - Mirai-greeth_flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 83495 (69.95%)
# 	Mirai-greeth_flood - 35862 (30.05%)
# TEST dataset:
# 	BenignTraffic - 20836 (70.12%)
# 	Mirai-greeth_flood - 8880 (29.88%)
#
#
# 18/28 - Mirai-greip_flood-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108345 (69.96%)
# 	Mirai-greip_flood - 46529 (30.04%)
# TEST dataset:
# 	BenignTraffic - 27395 (70.13%)
# 	Mirai-greip_flood - 11666 (29.87%)
#
#
# 19/28 - Mirai-udpplain-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 81371 (69.97%)
# 	Mirai-udpplain - 34917 (30.03%)
# TEST dataset:
# 	BenignTraffic - 20402 (69.95%)
# 	Mirai-udpplain - 8764 (30.05%)
#
#
# 20/28 - MITM-ArpSpoofing-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 38665 (69.96%)
# 	MITM-ArpSpoofing - 16605 (30.04%)
# TEST dataset:
# 	BenignTraffic - 9652 (69.41%)
# 	MITM-ArpSpoofing - 4254 (30.59%)
#
#
# 21/28 - Recon-HostDiscovery-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108652 (17.74%)
# 	Recon-HostDiscovery - 503810 (82.26%)
# TEST dataset:
# 	BenignTraffic - 27088 (17.7%)
# 	Recon-HostDiscovery - 125989 (82.3%)
#
#
# 22/28 - Recon-OSScan-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108628 (45.28%)
# 	Recon-OSScan - 131290 (54.72%)
# TEST dataset:
# 	BenignTraffic - 27112 (45.33%)
# 	Recon-OSScan - 32692 (54.67%)
#
#
# 23/28 - Recon-PingSweep-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 1939 (70.43%)
# 	Recon-PingSweep - 814 (29.57%)
# TEST dataset:
# 	BenignTraffic - 481 (68.62%)
# 	Recon-PingSweep - 220 (31.38%)
#
#
# 24/28 - Recon-PortScan-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108317 (40.43%)
# 	Recon-PortScan - 159567 (59.57%)
# TEST dataset:
# 	BenignTraffic - 27423 (40.83%)
# 	Recon-PortScan - 39746 (59.17%)
#
#
# 25/28 - SqlInjection-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 6713 (70.2%)
# 	SqlInjection - 2849 (29.8%)
# TEST dataset:
# 	BenignTraffic - 1750 (71.55%)
# 	SqlInjection - 696 (28.45%)
#
#
# 26/28 - Uploading_Attack-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 528 (69.66%)
# 	Uploading_Attack - 230 (30.34%)
# TEST dataset:
# 	BenignTraffic - 152 (73.08%)
# 	Uploading_Attack - 56 (26.92%)
#
#
# 27/28 - VulnerabilityScan-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 108554 (33.57%)
# 	VulnerabilityScan - 214857 (66.43%)
# TEST dataset:
# 	BenignTraffic - 27186 (33.44%)
# 	VulnerabilityScan - 54107 (66.56%)
#
#
# 28/28 - XSS-shuffled
# ======================
# TRAIN dataset:
# 	BenignTraffic - 1378 (69.53%)
# 	XSS - 604 (30.47%)
# TEST dataset:
# 	BenignTraffic - 340 (71.58%)
# 	XSS - 135 (28.42%)
